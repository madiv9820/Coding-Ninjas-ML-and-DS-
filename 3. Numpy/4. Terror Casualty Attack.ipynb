# %% [markdown]
# Problem statement
# Given file "terrorismData.csv"
#
# It is an open-source database including information on terrorist attacks around the world from 1970 through 2017. This dataset includes systematic data on domestic as well as international terrorist incidents that have occurred during this time period
#
# Problem Statement :
# As we knew the Kargil ( in Jammu and Kashmir) War that took place between May 1999 and July 1999 (3 Months) ,so there was a huge conflict in Kashmir Valley during this period.
#
# In this dataset, there is no information regarding the war between the two countries to find out the casualty during the war.
#
# So find out the attack in this period in which maximum casualties happened.
#
# Print the count of casualties (as integer), city in which that attack happened and name of attack group.
#
# Note : Casualty = Killed + Wounded.Fill the empty value in killed or wounded feature to 0.
#
# Output Format :
# Casualty City TerroristGroup
# import numpy as np
# import csv
# with open('terrorismData.csv') as file:
#     data = csv.DictReader(file, skipinitialspace = True)
#     k,w,s,c,g = [],[],[],[],[]
#     for r in data:
#         if r['State'] == 'Jammu and Kashmir' and r['Month'] >= '5' and r['Month'] <= '7' and r['Year'] == '1999':
#             k.append(r['Killed'])
#             w.append(r['Wounded'])
#             c.append(r['City'])

# %%
import csv
import numpy as np
from collections import defaultdict

with open('terrorismData.csv') as data:
    terrorism_Data = csv.DictReader(data, skipinitialspace = True)
    killed, wounded, cities, states, terrorist_groups = [], [], [], [], []
    months, years = [], []
    
    for row in terrorism_Data:
        killed.append(row['Killed'])
        wounded.append(row['Wounded'])
        cities.append(row['City'])
        states.append(row['State'])
        terrorist_groups.append(row['Group'])
        months.append(row['Month'])
        years.append(row['Year'])
        
    killed = np.array(killed)
    wounded = np.array(wounded)
    terrorist_groups = np.array(terrorist_groups)
    states = np.array(states)
    
    killed[killed == ''] = '0.0'
    wounded[wounded == ''] = '0.0'
    
    killed = np.array(np.array(killed, dtype = float), dtype = int)
    wounded = np.array(np.array(wounded, dtype = float), dtype = int)
    
    cities = np.array(cities)
    months = np.array(months, dtype = int)
    years = np.array(years, dtype = int)
    
    condition = (states == 'Jammu and Kashmir') & (months >= 5) & (months <= 7) & (years == 1999)
    killed = killed[condition]
    wounded = wounded[condition]
    cities = cities[condition]
    terrorist_groups = terrorist_groups[condition]
    
    casualities = killed + wounded
    city_data = defaultdict(list)    
    
#     for city in cities:
#         terror_data = defaultdict(int)
#         terrorist_Groups_For_City = terrorist_groups[cities == city]
#         casualities_For_City = casualities[cities == city]
        
#         for terrorist_Group in terrorist_Groups_For_City:
#             casualities_For_Terrorist_Group = np.sum(casualities_For_City[terrorist_Groups_For_City == terrorist_Group])
#             if casualities_For_Terrorist_Group > 0: terror_data[terrorist_Group] = casualities_For_Terrorist_Group
        
#         if len(terror_data) > 0: city_data[city].append(terror_data)
        
#     for city, terror_data in city_data.items():
#         for data in terror_data:
#             for group, cas in data.items():
#                 print(cas, city, group)
    
    index = np.argmax(casualities)
    print('Maximum Terrorist Attack:', casualities[index], cities[index], terrorist_groups[index])
# Out:
# 3 Dadsara Hizbul Mujahideen (HM)
# 10 Lasana Unknown
# 22 Kargil District Separatists
# 3 Kupwara District Unknown
# 3 Kupwara District Unknown
# 7 Kangan Unknown
# 9 Srinagar Unknown
# 5 Rajouri District Unknown
# 15 Mohra Bachai Unknown
# 12 Sangam Unknown
# 17 Surankot Unknown
# 20 Anantnag Unknown
# 20 Anantnag Unknown
# 9 Poonch District Unknown
# 1 Madar Lashkar-e-Taiba (LeT)
# 7 Bandipora Unknown
# 20 Lehota Hizbul Mujahideen (HM)
# 5 Mandi Hizbul Mujahideen (HM)
# 17 Baramulla Unknown
# Maximum Terrorist Attack: 22 Kargil District Separatists
